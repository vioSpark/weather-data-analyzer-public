# %%
import pandas as pd
import numpy as np
import random
import pstats
from pstats import SortKey

# %%
stats=pstats.Stats('profile_data_01')
stats.strip_dirs().sort_stats(SortKey.TIME).print_stats()
# Out:
# Wed Nov 14 21:15:55 2018    profile_data_01
#
#          448528647 function calls (443637882 primitive calls) in 451.511 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#  77068967   23.592    0.000   36.951    0.000 {built-in method builtins.isinstance}
#    292200   14.535    0.000   14.535    0.000 datamanipulator.py:537(to_excel_date)
#   1516570   12.680    0.000   12.680    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    452982   11.371    0.000  131.898    0.000 indexing.py:298(_setitem_with_indexer)
#       675   11.244    0.017  384.663    0.570 datamanipulator.py:338(create_conditional_contingency_table)
#   2077216   10.384    0.000   18.183    0.000 indexing.py:1976(_is_scalar_access)
#   1772197    9.154    0.000    9.977    0.000 common.py:86(_maybe_box_datetimelike)
# 38158796/33440661    8.669    0.000   13.921    0.000 {built-in method builtins.len}
# ...

# %%
# %load_ext snakeviz
# Out:
# The snakeviz extension is already loaded. To reload it, use:
#   %reload_ext snakeviz

# %%
snakeviz profile_data_01
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-a9ba99b6f75e> in <module>
# ----> 1 get_ipython().run_line_magic('snakeviz', 'profile_data_01.prof')
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2285                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2286             with self.builtin_trap:
# -> 2287                 result = fn(*args,**kwargs)
#    2288             return result
#    2289
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\snakeviz\ipymagic.py in snakeviz_magic(line, cell)
#      24         ip.run_cell_magic('prun', line, cell)
#      25     else:
# ---> 26         ip.run_line_magic('prun', line)
#      27
#      28     # start up a Snakeviz server
#
# ...
